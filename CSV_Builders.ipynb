# %%
import pandas as pd
import numpy as np
import seaborn as sns
import json
import os
import glob
import codecs
import csv

# %%
import glob
import pandas as pd

fds = []
for f in glob.glob("../atp_matches/atp_matches*.csv"):
    fds.append(pd.read_csv(f))

frame = pd.concat(fds)

# %%
#frame has all the atp matches
#so made main df - to become csv later
frame.tail(10)
# Out:
#      tourney_id                tourney_name surface  draw_size tourney_level  \
# 2891   2014-605                 Tour Finals    Hard          8             F
# 2892   2014-605                 Tour Finals    Hard          8             F
# 2893   2014-605                 Tour Finals    Hard          8             F
# 2894   2014-605                 Tour Finals    Hard          8             F
# 2895   2014-605                 Tour Finals    Hard          8             F
# 2896   2014-605                 Tour Finals    Hard          8             F
# 2897   2014-605                 Tour Finals    Hard          8             F
# 2898  2014-D015  Davis Cup WG F: FRA vs SUI    Clay          4             D
# 2899  2014-D015  Davis Cup WG F: FRA vs SUI    Clay          4             D
# 2900  2014-D015  Davis Cup WG F: FRA vs SUI    Clay          4             D
#
#       tourney_date  match_num  winner_id  winner_seed winner_entry  ...  \
# ...

# %%
ATP.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points',
#        'FirstServe', 'First_Serve_Win', 'First_Serve'],
#       dtype='object')

# %%
ATP.isnull().sum()
# Out:
# tourney_id                 0
# tourney_name               0
# surface                 2439
# draw_size                  0
# tourney_level              0
# tourney_date               0
# match_num                  0
# winner_id                  0
# winner_seed           111845
# winner_entry          164460
# winner_name                0
# winner_hand               60
# winner_ht              18754
# winner_ioc                 8
# winner_age              1971
# loser_id                   0
# loser_seed            145681
# loser_entry           153238
# loser_name                 0
# loser_hand               141
# loser_ht               31084
# loser_ioc                 55
# loser_age               5721
# score                     11
# best_of                    0
# round                      0
# minutes                93433
# w_ace                  90830
# w_df                   90830
# w_svpt                 90830
# w_1stIn                90830
# w_1stWon               90830
# ...

# %%
ATP.score
# Out:
# 0           6-4 3-6 6-2
# 1            7-6(6) 6-2
# 2               6-2 6-2
# 3            6-4 7-6(2)
# 4        6-7(2) 6-3 6-4
#              ...
# 2896        6-1 3-6 6-0
# 2897                W/O
# 2898    6-1 3-6 6-3 6-2
# 2899        6-1 6-4 6-3
# 2900        6-4 6-2 6-2
# Name: score, Length: 180305, dtype: object

# %%
ATP.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points',
#        'FirstServe', 'First_Serve_Win', 'First_Serve'],
#       dtype='object')

# %%
ATP.head(1)
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2019-M020     Brisbane    Hard         32             A      20181231
#
#    match_num  winner_id  winner_seed winner_entry  ... l_SvGms l_bpSaved  \
# 0        300     105453          2.0          NaN  ...    14.0      10.0
#
#    l_bpFaced winner_rank  winner_rank_points  loser_rank  loser_rank_points  \
# 0       15.0         9.0              3590.0        16.0             1977.0
#
#   FirstServe First_Serve_Win First_Serve
# 0   0.571429        0.704545    0.571429
#
# [1 rows x 52 columns]

# %%
ATP.tourney_level.value_counts()
# Out:
# A    117327
# G     26014
# M     22329
# D     14101
# F       534
# Name: tourney_level, dtype: int64

# %%
### BUILT ATPTotal for all ATP matches combined
#frame.to_csv('ATPTotal.csv')

# %%
# save under new name
ATP = frame

# %%
# Win Count DF
win_count = ATP.groupby('winner_id')[['winner_name']].agg('count').sort_values(by='winner_id').astype(int).reset_index()
win_count = win_count.rename(columns={'winner_name': 'win_count', 'winner_id' : 'PlayerID'})
win_count
# Out:
#       PlayerID  win_count
# 0       100002          3
# 1       100003         10
# 2       100004          4
# 3       100005        126
# 4       100007          4
# ...        ...        ...
# 3855    209870          1
# 3856    209874          1
# 3857    210013        158
# 3858    210079          1
# 3859    210107          1
#
# [3860 rows x 2 columns]

# %%
# Loss Count DF
loss_count = ATP.groupby('loser_id')[['loser_name']].agg('count').sort_values(by='loser_id').astype(int).reset_index()
loss_count = loss_count.rename(columns={'loser_name': 'lose_count', 'loser_id' : 'PlayerID'})
loss_count
# Out:
#       PlayerID  lose_count
# 0       100001           2
# 1       100002           5
# 2       100003          17
# 3       100004          10
# 4       100005          54
# ...        ...         ...
# 6349    209903           1
# 6350    209916           1
# 6351    210013         212
# 6352    210250           1
# 6353    210274           1
#
# [6354 rows x 2 columns]

# %%
#First Serve win percentage added new column
ATP['W_First_Serve'] = ATP['w_1stIn'] / ATP['w_svpt']
#First Serve Win
ATP['W_First_Serve_Win'] = ATP['w_1stWon'] / ATP['w_1stIn']
#Break Points? (have mason define)

# %% [markdown]
# #### questions:
# - Breakpoints and other feature engineering
# - Should we avoid point system (cause overfitting?)
# - Trim DF at what amount of game wins?
# -

# %%
ATP.head(1)
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2019-M020     Brisbane    Hard         32             A      20181231
#
#    match_num  winner_id  winner_seed winner_entry  ... l_2ndWon l_SvGms  \
# 0        300     105453          2.0          NaN  ...     20.0    14.0
#
#    l_bpSaved l_bpFaced  winner_rank  winner_rank_points  loser_rank  \
# 0       10.0      15.0          9.0              3590.0        16.0
#
#   loser_rank_points FirstServe First_Serve_Win
# 0            1977.0   0.571429        0.704545
#
# [1 rows x 51 columns]

# %%
### built this out in feature building notebook

# %%
#Create dataframe for Player Data and label columns
PlayerColumns = ['PlayerID', 'Player_Name', 'Age', 'Height', 'MaxRank', 'Hand', 'Country', 'First_Serve_%', 'First_Serve_Win_%']

PlayerData = pd.DataFrame(columns = PlayerColumns)
PlayerData.set_index('PlayerID')


#Add data to the PlayerData dataframe
for index, row in ATP.iterrows():
    #player was the winner
    p_id = int(row.winner_id)
    
    #Check value
    if(p_id not in PlayerData.index):
        PlayerData.loc[p_id] = [p_id, row.winner_name, row.winner_age, row.winner_ht, row.winner_rank, row.winner_hand, row.winner_ioc]

    #Update rank with best rank value
    if(row.winner_rank < PlayerData.loc[p_id].MaxRank and not np.isnan(PlayerData.loc[p_id].MaxRank)):
        PlayerData.loc[p_id] = [p_id, row.winner_name, row.winner_age, row.winner_ht, row.winner_rank, row.winner_hand, row.winner_ioc]

    #Player was loser
    p2_id = int(row.loser_id)
    #Check for loser
    if(p2_id not in PlayerData.index):
        PlayerData.loc[p2_id] = [p2_id, row.loser_name, row.loser_age, row.loser_ht, row.loser_rank, row.loser_hand, row.loser_ioc]

    #Update rank with best rank value
    if(row.loser_rank < PlayerData.loc[p2_id].MaxRank and not np.isnan(PlayerData.loc[p2_id].MaxRank)):
        PlayerData.loc[p2_id] = [p2_id, row.loser_name, row.loser_age, row.loser_ht, row.loser_rank, row.loser_hand, row.loser_ioc]

# %%
#Create dataframe for Player Data and label columns
PlayerColumns = ['PlayerID', 'PName', 'Age', 'Height', 'MaxRank', 'Hand', 'Country']

PlayerData = pd.DataFrame(columns = PlayerColumns)
PlayerData.set_index('PlayerID')


#Add data to the PlayerData dataframe
for index, row in ATPData.head(50180).iterrows():
    #If player was the winner
    p_id = int(row.winner_id)
    
    #Check if value exists or not
    if(p_id not in PlayerData.index):
        PlayerData.loc[p_id] = [p_id, row.winner_name, row.winner_age, row.winner_ht, row.winner_rank, row.winner_hand, row.winner_ioc]

    #Update rank with best rank value
    if(row.winner_rank < PlayerData.loc[p_id].MaxRank and not np.isnan(PlayerData.loc[p_id].MaxRank)):
        PlayerData.loc[p_id] = [p_id, row.winner_name, row.winner_age, row.winner_ht, row.winner_rank, row.winner_hand, row.winner_ioc]
    
    else:
        PlayerData.loc[p_id] = [p_id, row.winner_name, row.winner_age, row.winner_ht, PlayerData.loc[p_id].MaxRank, row.winner_hand, row.winner_ioc]
   

    #If the player lost
    p_id2 = int(row.loser_id)
    
    #Check if value exists or not
    if(p_id2 not in PlayerData.index):
        PlayerData.loc[p_id2] = [p_id2, row.loser_name, row.loser_age, row.loser_ht, row.loser_rank, row.loser_hand, row.loser_ioc]

    if(row.loser_rank < PlayerData.loc[p_id2].MaxRank and not np.isnan(PlayerData.loc[p_id2].MaxRank)):
        PlayerData.loc[p_id2] = [p_id2, row.loser_name, row.loser_age, row.loser_ht, row.loser_rank, row.loser_hand, row.loser_ioc]

    else:
        PlayerData.loc[p_id2] = [p_id2, row.loser_name, row.loser_age, row.loser_ht, PlayerData.loc[p_id2].MaxRank, row.loser_hand, row

# %%
PlayerData
# Out:
#        PlayerID         Player_Name        Age  Height  MaxRank Hand Country  \
# 105453   105453       Kei Nishikori  26.839151   178.0      4.0    R     JPN
# 106421   106421     Daniil Medvedev  25.434634   198.0      2.0    R     RUS
# 104542   104542  Jo-Wilfried Tsonga  26.863792   188.0      5.0    R     FRA
# 104871   104871       Jeremy Chardy  25.998631   188.0     25.0    R     FRA
# 200282   200282      Alex De Minaur  22.360027   183.0     15.0    R     AUS
# ...         ...                 ...        ...     ...      ...  ...     ...
# 105059   105059      Kento Takeuchi  26.759754     NaN    441.0    L     JPN
# 104393   104393   Gregoire Burquier  30.206708     NaN    205.0    L     FRA
# 105999   105999        Bowen Ouyang  22.343600     NaN   1098.0    L     CHN
# 106321   106321             Xin Gao  20.364134     NaN    944.0    U     CHN
# 106066   106066       Victor Baluda  22.034223     NaN    466.0    R     RUS
#
#         First_Serve_%  First_Serve_Win_%
# ...

# %%
### money for merge

from functools import reduce

data_frames = [PlayerData, win_count, loss_count]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['PlayerID'],
                                            how='left'), data_frames)
df_merged
# Out:
#      PlayerID         Player_Name        Age  Height  MaxRank Hand Country  \
# 0      105453       Kei Nishikori  26.839151   178.0      4.0    R     JPN
# 1      106421     Daniil Medvedev  25.434634   198.0      2.0    R     RUS
# 2      104542  Jo-Wilfried Tsonga  26.863792   188.0      5.0    R     FRA
# 3      104871       Jeremy Chardy  25.998631   188.0     25.0    R     FRA
# 4      200282      Alex De Minaur  22.360027   183.0     15.0    R     AUS
# ...       ...                 ...        ...     ...      ...  ...     ...
# 6485   105059      Kento Takeuchi  26.759754     NaN    441.0    L     JPN
# 6486   104393   Gregoire Burquier  30.206708     NaN    205.0    L     FRA
# 6487   105999        Bowen Ouyang  22.343600     NaN   1098.0    L     CHN
# 6488   106321             Xin Gao  20.364134     NaN    944.0    U     CHN
# 6489   106066       Victor Baluda  22.034223     NaN    466.0    R     RUS
#
#       First_Serve_%  First_Serve_Win_%  win_count  lose_count
# ...

# %%
# adding Win%
df_merged['Win%'] = round((df_merged['win_count']/ df_merged['lose_count']),2)

# %%
### SAVE IT FOR CSV (MANY UPDATES NEEDED)
#df_merged.to_csv('PlayerData.csv')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-135-37dfd44a9bc6> in <module>
# ----> 1 df_merged.score
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'score'

# %%
df_merged[df_merged['MaxRank']==1]
# Out:
#      PlayerID          Player_Name        Age  Height  MaxRank Hand Country  \
# 10     104918          Andy Murray  29.503080   190.0      1.0    R     GBR
# 30     104925       Novak Djokovic  31.611225   188.0      1.0    R     SRB
# 109    104745         Rafael Nadal  33.440110   185.0      1.0    L     ESP
# 110    103819        Roger Federer  36.572211   185.0      1.0    R     SUI
# 583    102845          Carlos Moya  22.546201   190.0      1.0    R     ESP
# 600    104053         Andy Roddick  21.349760   188.0      1.0    R     USA
# 609    103498          Marat Safin  21.065024   193.0      1.0    R     RUS
# 629    103507  Juan Carlos Ferrero  23.665982   183.0      1.0    R     ESP
# 669    103720       Lleyton Hewitt  21.289528   180.0      1.0    R     AUS
# 1162   100581         John McEnroe  22.480493   180.0      1.0    L     USA
# 1171   100119         Ilie Nastase  27.277207   183.0      1.0    R     ROU
# ...

# %% [markdown]
# Player ID use as a foreign winner id and loser id

# %% [markdown]
# pd.merge pass an array of column names - to join across multiple columns -
#
#
# - predicting who won based on game day stats of the match - each match would have to be turned into an observaiton in which there could be alternate target outcomes - split each match into two observations for each player - show us players this is how they perform and the outcome was either winner or loser - model will see what
#
# lets say a match occured - statistics of players vs each other - we should be able to feed
#
# - difference between stats -
#
# value of every target is winner (player1) nothing to train the model on where player2 wins but the model should
#
#
# iterate through a .unique - summary statistics - each variable for these players and build the two play
#
# under the assumption we aggregating to a single point in time,
#
#
# ----- MVP we are going to use all the stats we have prior to match -
